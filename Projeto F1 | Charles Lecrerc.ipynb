# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeEvCosta/Documentacao_Python_BD/blob/main/Projeto%20F1%20%7C%20Charles%20Lecrerc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏎️Projeto F1🏎️

# %% [markdown]
# ![aws .jfif](data:image/jpeg;base64,...)

# %% [markdown]
# # **Introdução**
# ---

# %% [markdown]
# # Instalando bibliotecas e importando

# %% [markdown]
# **Bibliotecas instaladas:**
#
# 1) boto3: Permite acessar e gerenciar serviços da AWS.
#
# 2) s3fs: Permite abrir, ler e escrever arquivos no S3 como se fosse um sistema de arquivos local.
#
# 3) pandas: Trabalha com tabelas (DataFrames), facilita leitura, filtro, agregação e limpeza de dados.
#
# 4) Numpy: Cálculos numéricos, especialmente com arrays multidimensionais, oferecendo operações rápidas e otimizadas para matemática, álgebra linear e análise de dados.
#
# 5) Matplotlib.pyplot: Criar gráficos e visualizações de dados em Python

# %%
# !pip install boto3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 45.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 5.7 MB/s eta 0:00:00
# ...

# %%
# !pip install s3fs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 56.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.39.16
#     Uninstalling botocore-1.39.16:
#       Successfully uninstalled botocore-1.39.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.39.16 requires botocore<1.40.0,>=1.39.16, but you have botocore 1.39.8 which is incompatible.
# ...

# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
# !pip install matplotlib

# %%
#Importação das bibliotecas baixadas
import boto3
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Acesso ao Bucket S3

# %%
#Acessando AWS, utilizando credênciais de acesso
os.environ["AWS_ACCESS_KEY_ID"] = "AKIARPI6CTRKOSWYXYG5"
os.environ["AWS_SECRET_ACCESS_KEY"] = "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"

# %% [markdown]
# # Acessando base e validando Info

# %%
#Lendo CSV diretamente do bucket S3
bucket = "testeguilherme-bucket1"
path = "f12022/Formula1_2022season_calendar.csv"

Formula1_2022 = pd.read_csv("s3://testeguilherme-bucket1/f12022/Formula1_2022season_calendar.csv")
Formula1_2022.head(2)  # Mostra as primeiras linhas
# Out:
#    Round   Race Date               GP Name       Country    City  \
# 0      1  20/03/2022   Gulf Air Bahrain GP       Bahrain  Sakhir
# 1      2  27/03/2022  STC Saudi Arabian GP  Saudi Arabia  Jeddah
#
#                     Circuit Name  First GP  Number of Laps  \
# 0  Bahrain International Circuit      2004              57
# 1        Jeddah Corniche Circuit      2021              50
#
#    Circuit Length(km)  Race Distance(km) Lap Record      Record Owner  \
# 0               5.412            308.238   1:31.447  Pedro de la Rosa
# 1               6.174            308.450   1:30.774    Lewis Hamilton
#
#    Record Year  Turns  DRS Zones
# 0         2005     15          3
# 1         2021     27          3

# %%
# Validação de N/A's

Formula1_2022.isna().any()
# Out:
# Round                 False
# Race Date             False
# GP Name               False
# Country               False
# City                  False
# Circuit Name          False
# First GP              False
# Number of Laps        False
# Circuit Length(km)    False
# Race Distance(km)     False
# Lap Record            False
# Record Owner          False
# Record Year           False
# Turns                 False
# DRS Zones             False
# dtype: bool

# %% [markdown]
# # **Tabela Calendário**
# ---

# %% [markdown]
# # Calendário 2022

# %%
# Ler o CSV diretamente do bucket S3
bucket = "testeguilherme-bucket1"
path = "pastaguilherme-teste/Formula1_2022season_calendar.csv"

Formula1_2022 = pd.read_csv("s3://testeguilherme-bucket1/f12022/Formula1_2022season_calendar.csv")
Formula1_2022.head(3)  # Mostra as primeiras linhas
# Out:
#    Round   Race Date                 GP Name       Country       City  \
# 0      1  20/03/2022     Gulf Air Bahrain GP       Bahrain     Sakhir
# 1      2  27/03/2022    STC Saudi Arabian GP  Saudi Arabia     Jeddah
# 2      3  10/04/2022  Heineken Australian GP     Australia  Melbourne
#
#                     Circuit Name  First GP  Number of Laps  \
# 0  Bahrain International Circuit      2004              57
# 1        Jeddah Corniche Circuit      2021              50
# 2            Albert Park Circuit      1996              58
#
#    Circuit Length(km)  Race Distance(km) Lap Record      Record Owner  \
# 0               5.412            308.238   1:31.447  Pedro de la Rosa
# 1               6.174            308.450   1:30.774    Lewis Hamilton
# 2               5.278            306.124   1:20.260   Charles Leclerc
#
#    Record Year  Turns  DRS Zones
# 0         2005     15          3
# 1         2021     27          3
# 2         2022     14          2

# %%
Formula1_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Round               22 non-null     int64
#  1   Race Date           22 non-null     object
#  2   GP Name             22 non-null     object
#  3   Country             22 non-null     object
#  4   City                22 non-null     object
#  5   Circuit Name        22 non-null     object
#  6   First GP            22 non-null     int64
#  7   Number of Laps      22 non-null     int64
#  8   Circuit Length(km)  22 non-null     float64
#  9   Race Distance(km)   22 non-null     float64
#  10  Lap Record          22 non-null     object
#  11  Record Owner        22 non-null     object
#  12  Record Year         22 non-null     int64
#  13  Turns               22 non-null     int64
#  14  DRS Zones           22 non-null     int64
# dtypes: float64(2), int64(6), object(7)
# ...

# %%
Formula1_2022.shape
# Out:
# (22, 15)

# %% [markdown]
# # Calendário 2023

# %%
# Ler o CSV diretamente do bucket S3
bucket = "testeguilherme-bucket1"
path = "pastaguilherme-teste/Formula1_2023season_calendar.csv"

Formula1_2023 = pd.read_csv("s3://testeguilherme-bucket1/f12023/Formula1_2023season_calendar.csv")
Formula1_2023.head(3)  # Mostra as primeiras linhas
# Out:
#    Round   Race Date               GP Name       Country       City  \
# 0      1  05/03/2023   Gulf Air Bahrain GP       Bahrain     Sakhir
# 1      2  19/03/2023  STC Saudi Arabian GP  Saudi Arabia     Jeddah
# 2      3  02/04/2023   Rolex Australian GP     Australia  Melbourne
#
#                     Circuit Name  First GP  Number of Laps  \
# 0  Bahrain International Circuit      2004              57
# 1        Jeddah Corniche Circuit      2021              50
# 2   Melbourne Grand Prix Circuit      1996              58
#
#    Circuit Length(km)  Race Distance(km) Lap Record      Record Owner  \
# 0               5.412            308.238   1:31.447  Pedro de la Rosa
# 1               6.174            308.450   1:30.734    Lewis Hamilton
# 2               5.278            306.124   1:20.235      Sergio Perez
#
#    Record Year  Turns  DRS Zones
# 0         2005     15          3
# 1         2021     27          3
# 2         2023     14          4

# %%
Formula1_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Round               23 non-null     int64
#  1   Race Date           22 non-null     object
#  2   GP Name             23 non-null     object
#  3   Country             23 non-null     object
#  4   City                23 non-null     object
#  5   Circuit Name        23 non-null     object
#  6   First GP            23 non-null     int64
#  7   Number of Laps      23 non-null     int64
#  8   Circuit Length(km)  23 non-null     float64
#  9   Race Distance(km)   23 non-null     float64
#  10  Lap Record          23 non-null     object
#  11  Record Owner        23 non-null     object
#  12  Record Year         23 non-null     int64
#  13  Turns               23 non-null     int64
#  14  DRS Zones           23 non-null     int64
# dtypes: float64(2), int64(6), object(7)
# ...

# %%
Formula1_2023.shape
# Out:
# (23, 15)

# %% [markdown]
# # Calendário 2024

# %%
# Ler o CSV diretamente do bucket S3
bucket = "testeguilherme-bucket1"
path = "pastaguilherme-teste/Formula1_2024season_calendar.csv"

Formula1_2024 = pd.read_csv("s3://testeguilherme-bucket1/f12024/Formula1_2024season_calendar.csv")
Formula1_2024.head(3)  # Mostra as primeiras linhas
# Out:
#    Round   Race Date               GP Name       Country       City  \
# 0      1  02/03/2024   Gulf Air Bahrain GP       Bahrain     Sakhir
# 1      2  09/03/2024  STC Saudi Arabian GP  Saudi Arabia     Jeddah
# 2      3  24/03/2024   Rolex Australian GP     Australia  Melbourne
#
#                      Circuit Name  First GP  Number of Laps  \
# 0   Bahrain International Circuit      2004              57
# 1         Jeddah Corniche Circuit      2021              50
# 2  Albert Park Grand Prix Circuit      1996              58
#
#    Circuit Length(km)  Race Distance(km) Lap Record      Record Owner  \
# 0               5.412            308.238   1:31.447  Pedro de la Rosa
# 1               6.174            308.450   1:30.734    Lewis Hamilton
# 2               5.278            306.124   1:19.813   Charles Leclerc
#
#    Record Year  Turns  DRS Zones
# 0         2005     15          3
# 1         2021     27          3
# 2         2024     14          4

# %%
Formula1_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Round               24 non-null     int64
#  1   Race Date           24 non-null     object
#  2   GP Name             24 non-null     object
#  3   Country             24 non-null     object
#  4   City                24 non-null     object
#  5   Circuit Name        24 non-null     object
#  6   First GP            24 non-null     int64
#  7   Number of Laps      24 non-null     int64
#  8   Circuit Length(km)  24 non-null     float64
#  9   Race Distance(km)   24 non-null     float64
#  10  Lap Record          24 non-null     object
#  11  Record Owner        24 non-null     object
#  12  Record Year         24 non-null     int64
#  13  Turns               24 non-null     int64
#  14  DRS Zones           24 non-null     int64
# dtypes: float64(2), int64(6), object(7)
# ...

# %%
Formula1_2024.shape
# Out:
# (24, 15)

# %% [markdown]
# # Calendário Consolidado (2022;2023 e 2024)

# %%
# Consolidar as bases
df_calendarioConsolidado = pd.concat([Formula1_2024, Formula1_2023, Formula1_2024], ignore_index=True)

# Visualizar resultado
df_calendarioConsolidado.head(3)
# Out:
#    Round   Race Date               GP Name       Country       City  \
# 0      1  02/03/2024   Gulf Air Bahrain GP       Bahrain     Sakhir
# 1      2  09/03/2024  STC Saudi Arabian GP  Saudi Arabia     Jeddah
# 2      3  24/03/2024   Rolex Australian GP     Australia  Melbourne
#
#                      Circuit Name  First GP  Number of Laps  \
# 0   Bahrain International Circuit      2004              57
# 1         Jeddah Corniche Circuit      2021              50
# 2  Albert Park Grand Prix Circuit      1996              58
#
#    Circuit Length(km)  Race Distance(km) Lap Record      Record Owner  \
# 0               5.412            308.238   1:31.447  Pedro de la Rosa
# 1               6.174            308.450   1:30.734    Lewis Hamilton
# 2               5.278            306.124   1:19.813   Charles Leclerc
#
#    Record Year  Turns  DRS Zones
# 0         2005     15          3
# 1         2021     27          3
# 2         2024     14          4

# %%
df_calendarioConsolidado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Round               71 non-null     int64
#  1   Race Date           70 non-null     object
#  2   GP Name             71 non-null     object
#  3   Country             71 non-null     object
#  4   City                71 non-null     object
#  5   Circuit Name        71 non-null     object
#  6   First GP            71 non-null     int64
#  7   Number of Laps      71 non-null     int64
#  8   Circuit Length(km)  71 non-null     float64
#  9   Race Distance(km)   71 non-null     float64
#  10  Lap Record          71 non-null     object
#  11  Record Owner        71 non-null     object
#  12  Record Year         71 non-null     int64
#  13  Turns               71 non-null     int64
#  14  DRS Zones           71 non-null     int64
# dtypes: float64(2), int64(6), object(7)
# ...

# %% [markdown]
# # >> Lecrerc e seus recordes de melhor volta

# %%
#Aplicando filtro para id~entificar piloto Lecrerc
df_calendarioConsolidado.loc[df_calendarioConsolidado['Record Owner'] == 'Charles Leclerc']
# Out:
#     Round   Race Date                      GP Name        Country       City  \
# 2       3  24/03/2024          Rolex Australian GP      Australia  Melbourne
# 16     17  15/09/2024  Qatar Airways Azerbaijan GP     Azerbaijan       Baku
# 18     19  20/10/2024     Pirelli United States GP  United States     Austin
# 27      4  30/04/2023                Azerbaijan GP     Azerbaijan       Baku
# 42     19  22/10/2023      Lenovo United States GP  United States     Austin
# 49      3  24/03/2024          Rolex Australian GP      Australia  Melbourne
# 63     17  15/09/2024  Qatar Airways Azerbaijan GP     Azerbaijan       Baku
# 65     19  20/10/2024     Pirelli United States GP  United States     Austin
#
#                       Circuit Name  First GP  Number of Laps  \
# 2   Albert Park Grand Prix Circuit      1996              58
# 16               Baku City Circuit      2016              51
# 18         Circuit of the Americas      2012              56
# ...

# %%
#Retirando dados duplicados
df_LecrercRecord = df_calendarioConsolidado.loc[
    df_calendarioConsolidado['Record Owner'] == 'Charles Leclerc'
].drop_duplicates(subset='City')

df_LecrercRecord.head(5)
# Out:
#     Round   Race Date                      GP Name        Country       City  \
# 2       3  24/03/2024          Rolex Australian GP      Australia  Melbourne
# 16     17  15/09/2024  Qatar Airways Azerbaijan GP     Azerbaijan       Baku
# 18     19  20/10/2024     Pirelli United States GP  United States     Austin
#
#                       Circuit Name  First GP  Number of Laps  \
# 2   Albert Park Grand Prix Circuit      1996              58
# 16               Baku City Circuit      2016              51
# 18         Circuit of the Americas      2012              56
#
#     Circuit Length(km)  Race Distance(km) Lap Record     Record Owner  \
# 2                5.278            306.124   1:19.813  Charles Leclerc
# 16               6.003            306.049   1:43.009  Charles Leclerc
# 18               5.513            308.405   1:36.169  Charles Leclerc
#
#     Record Year  Turns  DRS Zones
# 2          2024     14          4
# 16         2019     20          2
# ...

# %% [markdown]
# *Os recordes de volta rápida considerados são os race lap records (voltas mais rápidas durante a corrida oficial).
#
# **Race lap record: volta mais rápida de todas as edições oficiais da corrida naquela pista.

# %% [markdown]
# # **Tabela Qualifying**
# ---

# %% [markdown]
# # Qualifying 2022

# %%
# Leitura do arquivo CSV diretamente do S3
qualifyingF1_2022 = pd.read_csv("s3://testeguilherme-bucket1/f12022/Formula1_2022season_qualifyingResults.csv")

# Filtrar somente as linhas onde o piloto é Charles Leclerc
qualifyingF1_2022 = qualifyingF1_2022[qualifyingF1_2022['Driver'] == 'Charles Leclerc']


qualifyingF1_2022.head(2)  # Mostra as primeiras linhas
# Out:
#            Track Position  No           Driver     Team        Q1        Q2  \
# 0        Bahrain        1  16  Charles Leclerc  Ferrari  1:31.471  1:30.932
# 21  Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:29.039  1:28.780
#
#           Q3  Laps
# 0   1:30.558    15
# 21  1:28.225    22

# %%
# Leitura do CSV
qualifyingF1_2022 = pd.read_csv("s3://testeguilherme-bucket1/f12022/Formula1_2022season_qualifyingResults.csv")

# Filtro pelo piloto Charles Leclerc
qualifying_f12022_new = qualifyingF1_2022[qualifyingF1_2022['Driver'] == 'Charles Leclerc']

# Adicionar coluna "Year" com valor 2022
qualifying_f12022_new['Year'] = 2022

qualifying_f12022_new.head(2)
# Out:
# /tmp/ipython-input-25-849637989.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualifying_f12022_new['Year'] = 2022
#            Track Position  No           Driver     Team        Q1        Q2  \
# 0        Bahrain        1  16  Charles Leclerc  Ferrari  1:31.471  1:30.932
# 21  Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:29.039  1:28.780
#
#           Q3  Laps  Year
# 0   1:30.558    15  2022
# 21  1:28.225    22  2022

# %% [markdown]
# # Qualifying 2023

# %%
# Leitura do arquivo CSV diretamente do S3
qualifyingF1_2023 = pd.read_csv("s3://testeguilherme-bucket1/f12023/Formula1_2023season_qualifyingResults.csv")

# Filtrar somente as linhas onde o piloto é Charles Leclerc
qualifyingF1_2023 = qualifyingF1_2023[qualifyingF1_2023['Driver'] == 'Charles Leclerc']


qualifyingF1_2023.head(2)  # Mostra as primeiras linhas
# Out:
#            Track Position  No           Driver     Team        Q1        Q2  \
# 2        Bahrain        3  16  Charles Leclerc  Ferrari  1:31.094  1:30.282
# 21  Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:29.376  1:28.903
#
#           Q3  Laps
# 2   1:30.000    17
# 21  1:28.420    19

# %%
# Leitura do CSV
qualifyingF1_2023 = pd.read_csv("s3://testeguilherme-bucket1/f12023/Formula1_2023season_qualifyingResults.csv")

# Filtro pelo piloto Charles Leclerc
qualifying_f12023_new = qualifyingF1_2023[qualifyingF1_2023['Driver'] == 'Charles Leclerc']

# Adicionar coluna "Year" com valor 2022
qualifying_f12023_new['Year'] = 2023

qualifying_f12023_new.head(2)
# Out:
# /tmp/ipython-input-27-3714699863.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualifying_f12023_new['Year'] = 2023
#            Track Position  No           Driver     Team        Q1        Q2  \
# 2        Bahrain        3  16  Charles Leclerc  Ferrari  1:31.094  1:30.282
# 21  Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:29.376  1:28.903
#
#           Q3  Laps  Year
# 2   1:30.000    17  2023
# 21  1:28.420    19  2023

# %% [markdown]
# # Qualifying 2024

# %%
# Leitura do arquivo CSV diretamente do S3
qualifyingF1_2024 = pd.read_csv("s3://testeguilherme-bucket1/f12024/Formula1_2024season_qualifyingResults.csv")

# Filtrar somente as linhas onde o piloto é Charles Leclerc
qualifyingF1_2024 = qualifyingF1_2024[qualifyingF1_2024['Driver'] == 'Charles Leclerc']


qualifyingF1_2024.head(2)  # Mostra as primeiras linhas
# Out:
#            Track Position  No           Driver     Team        Q1        Q2  \
# 1        Bahrain        2  16  Charles Leclerc  Ferrari  1:30.243  1:29.165
# 21  Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:28.318  1:28.112
#
#           Q3  Laps
# 1   1:29.407    19
# 21  1:27.791    23

# %%
# Leitura do CSV
qualifyingF1_2024 = pd.read_csv("s3://testeguilherme-bucket1/f12024/Formula1_2024season_qualifyingResults.csv")

# Filtro pelo piloto Charles Leclerc
qualifying_f12024_new = qualifyingF1_2024[qualifyingF1_2024['Driver'] == 'Charles Leclerc']

# Adicionar coluna "Year" com valor 2022
qualifying_f12024_new['Year'] = 2024

qualifying_f12024_new.head(2)
# Out:
# /tmp/ipython-input-29-3088147373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualifying_f12024_new['Year'] = 2024
#            Track Position  No           Driver     Team        Q1        Q2  \
# 1        Bahrain        2  16  Charles Leclerc  Ferrari  1:30.243  1:29.165
# 21  Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:28.318  1:28.112
#
#           Q3  Laps  Year
# 1   1:29.407    19  2024
# 21  1:27.791    23  2024

# %% [markdown]
# # >> Qualifying Consolidado

# %%
# Consolidar as bases
df_qualifying_consolidado = pd.concat([qualifying_f12022_new, qualifying_f12023_new, qualifying_f12024_new], ignore_index=True)

# Visualizar resultado
df_qualifying_consolidado.head(2)
# Out:
#           Track Position  No           Driver     Team        Q1        Q2  \
# 0       Bahrain        1  16  Charles Leclerc  Ferrari  1:31.471  1:30.932
# 1  Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:29.039  1:28.780
#
#          Q3  Laps  Year
# 0  1:30.558    15  2022
# 1  1:28.225    22  2022

# %%
# Idêntificando N/A's
df_qualifying_consolidado.isna().any()
# Out:
# Track       False
# Position    False
# No          False
# Driver      False
# Team        False
# Q1          False
# Q2           True
# Q3           True
# Laps        False
# Year        False
# dtype: bool

# %%
# Substituindo N/A's pelo termo Unqualified
df_qualifying_consolidado[['Q2', 'Q3']] = df_qualifying_consolidado[['Q2', 'Q3']].fillna('Unqualified')
df_qualifying_consolidado.isna().any()
# Out:
# Track       False
# Position    False
# No          False
# Driver      False
# Team        False
# Q1          False
# Q2          False
# Q3          False
# Laps        False
# Year        False
# dtype: bool

# %%
df_qualifying_consolidado.head(4)
# Out:
#             Track Position  No           Driver     Team        Q1        Q2  \
# 0         Bahrain        1  16  Charles Leclerc  Ferrari  1:31.471  1:30.932
# 1    Saudi Arabia        2  16  Charles Leclerc  Ferrari  1:29.039  1:28.780
# 2       Australia        1  16  Charles Leclerc  Ferrari  1:18.881  1:18.606
# 3  Emilia Romagna        2  16  Charles Leclerc  Ferrari  1:18.796  1:19.584
#
#          Q3  Laps  Year
# 0  1:30.558    15  2022
# 1  1:28.225    22  2022
# 2  1:17.868    21  2022
# 3  1:28.778    22  2022

# %% [markdown]
# # **Tabela Corridas**
# ---

# %% [markdown]
# # Corridas 2022

# %%
# Leitura do arquivo CSV diretamente do S3
race_f12022 = pd.read_csv("s3://testeguilherme-bucket1/f12022/Formula1_2022season_raceResults.csv")

# Substituir nomes das colunas
race_f12022 = race_f12022.rename(columns={
    "+1 Pt": "Set Fastest Lap",
    "Fastest Lap": "Fastest Lap Time"
})

# Filtrar somente as linhas onde o piloto é Charles Leclerc
race_f12022 = race_f12022[race_f12022['Driver'] == 'Charles Leclerc']

# Adicionar coluna "Year" com valor 2022
race_f12022['Year'] = 2022

race_f12022.head(3)  # Mostra as primeiras linhas
# Out:
#            Track Position  No           Driver     Team  Starting Grid  Laps  \
# 0        Bahrain        1  16  Charles Leclerc  Ferrari              1    57
# 21  Saudi Arabia        2  16  Charles Leclerc  Ferrari              2    50
# 40     Australia        1  16  Charles Leclerc  Ferrari              1    58
#
#    Time/Retired  Points Set Fastest Lap Fastest Lap Time  Year
# 0   1:37:33.584      26             Yes         1:34.570  2022
# 21       +0.549      19             Yes         1:31.634  2022
# 40  1:27:46.548      26             Yes         1:20.260  2022

# %%
race_f12022.shape
# Out:
# (22, 12)

# %% [markdown]
# # Corridas 2023

# %%
# Leitura do arquivo CSV diretamente do S3
race_f12023 = pd.read_csv("s3://testeguilherme-bucket1/f12023/Formula1_2023season_raceResults.csv")

# Filtrar somente as linhas onde o piloto é Charles Leclerc
race_f12023 = race_f12023[race_f12023['Driver'] == 'Charles Leclerc']

# Adicionar coluna "Year" com valor 2023
race_f12023['Year'] = 2023

race_f12023.head(3)  # Mostra as primeiras linhas
# Out:
#            Track Position  No           Driver     Team  Starting Grid  Laps  \
# 18       Bahrain       NC  16  Charles Leclerc  Ferrari              3    39
# 26  Saudi Arabia        7  16  Charles Leclerc  Ferrari             12    50
# 59     Australia       NC  16  Charles Leclerc  Ferrari              7     0
#
#    Time/Retired  Points Set Fastest Lap Fastest Lap Time  Year
# 18          DNF       0              No         1:37.170  2023
# 26      +43.162       6              No         1:33.056  2023
# 59          DNF       0              No              NaN  2023

# %%
race_f12023.shape
# Out:
# (22, 12)

# %% [markdown]
# # Corridas 2024

# %%
# Leitura do arquivo CSV diretamente do S3
race_f12024 = pd.read_csv("s3://testeguilherme-bucket1/f12024/Formula1_2024season_raceResults.csv")

# Filtrar somente as linhas onde o piloto é Charles Leclerc
race_f12024 = race_f12024[race_f12024['Driver'] == 'Charles Leclerc']

# Adicionar coluna "Year" com valor 2024
race_f12024['Year'] = 2024

race_f12024.head(3)  # Mostra as primeiras linhas
# Out:
#            Track Position  No           Driver     Team  Starting Grid  Laps  \
# 3        Bahrain        4  16  Charles Leclerc  Ferrari              2    57
# 22  Saudi Arabia        3  16  Charles Leclerc  Ferrari              2    50
# 41     Australia        2  16  Charles Leclerc  Ferrari              4    58
#
#    Time/Retired  Points Set Fastest Lap Fastest Lap Time  Year
# 3       +39.669      12              No         1:34.090  2024
# 22      +18.639      16             Yes         1:31.632  2024
# 41       +2.366      19             Yes         1:19.813  2024

# %%
race_f12024.shape
# Out:
# (24, 12)

# %% [markdown]
# # >> Corridas Consolidado

# %%
# Consolidar as bases
df_race_consolidado = pd.concat([race_f12022, race_f12023, race_f12024], ignore_index=True)
df_race_consolidado[['Fastest Lap Time']] = df_race_consolidado [['Fastest Lap Time']].fillna('-')
df_race_consolidado.isna().any()

# Substituir "NC" e "DQ" por "0" na coluna 'Position'
df_race_consolidado['Position'] = df_race_consolidado['Position'].replace(['NC', 'DQ'], '0')

# Preencher valores NaN com "0" na coluna 'Position'
df_race_consolidado['Position'] = df_race_consolidado['Position'].fillna('0')

# Verificar se ainda existem valores nulos
df_race_consolidado.isna().any()

# Converter a coluna para inteiro
df_race_consolidado['Position'] = df_race_consolidado['Position'].astype(int)


# Visualizar resultado
df_race_consolidado.head(2)
# Out:
#           Track  Position  No           Driver     Team  Starting Grid  Laps  \
# 0       Bahrain         1  16  Charles Leclerc  Ferrari              1    57
# 1  Saudi Arabia         2  16  Charles Leclerc  Ferrari              2    50
#
#   Time/Retired  Points Set Fastest Lap Fastest Lap Time  Year
# 0  1:37:33.584      26             Yes         1:34.570  2022
# 1       +0.549      19             Yes         1:31.634  2022

# %% [markdown]
# # **Salvando**
# ---

# %%
# Salvar o DataFrame Race Consolidado diretamente no S3
df_race_consolidado.to_csv("s3://testeguilherme-bucket1/f1consolidado/df_race_consolidado.csv", index=False)

# %%
# Salvar o DataFrame Qualifying Consolidado diretamente no S3
df_qualifying_consolidado.to_csv("s3://testeguilherme-bucket1/f1consolidado/df_qualifying_consolidado.csv", index=False)

# %%
# Salvar o DataFrame Lecrerc Record diretamente no S3
df_LecrercRecord.to_csv("s3://testeguilherme-bucket1/f1consolidado/df_LecrercRecord.csv", index=False)

# %% [markdown]
# # **Tabela Mediana e Estatistica**
# ---

# %%
# Visualizar resultado
df_race_consolidado.head(2)
# Out:
#           Track  Position  No           Driver     Team  Starting Grid  Laps  \
# 0       Bahrain         1  16  Charles Leclerc  Ferrari              1    57
# 1  Saudi Arabia         2  16  Charles Leclerc  Ferrari              2    50
#
#   Time/Retired  Points Set Fastest Lap Fastest Lap Time  Year
# 0  1:37:33.584      26             Yes         1:34.570  2022
# 1       +0.549      19             Yes         1:31.634  2022

# %% [markdown]
# **Criando tabela Mediana**

# %%
# Calcular a mediana de Starting Grid por pista (Track)
mediana_grid = df_race_consolidado.groupby('Track')['Starting Grid'].median().reset_index()
mediana_grid.columns = ['Track', 'Median Grid']

# Calcular a mediana de Position por pista (Track)
mediana_posicao = df_race_consolidado.groupby('Track')['Position'].median().reset_index()
mediana_posicao.columns = ['Track', 'Median Position']

# Arredondar as medianas para cima
mediana_grid['Median Grid'] = np.ceil(mediana_grid['Median Grid']).astype(int)
mediana_posicao['Median Position'] = np.ceil(mediana_posicao['Median Position']).astype(int)

# Juntar as duas medianas ao DataFrame original
df_race_consolidado_graph = df_race_consolidado.merge(mediana_posicao, on='Track', how='left')
df_race_consolidado_graph = df_race_consolidado_graph.merge(mediana_grid, on='Track', how='left')

# Criar novo DataFrame com as colunas desejadas, sem duplicidade por Track
df_race_median = df_race_consolidado_graph[['Driver', 'Track', 'Median Grid', 'Median Position', 'Team']].drop_duplicates(subset='Track')

df_race_median.head(2)
# Out:
#             Driver         Track  Median Grid  Median Position     Team
# 0  Charles Leclerc       Bahrain            2                1  Ferrari
# 1  Charles Leclerc  Saudi Arabia            2                3  Ferrari

# %%
# Salvar o DataFrame Lecrerc Record diretamente no S3
df_race_median.to_csv("s3://testeguilherme-bucket1/f1consolidado/df_race_median.csv", index=False)

# %% [markdown]
# **Criando tabela Estatistica**

# %%
# 1. Criar o DataFrame com os dados da imagem
data_turns = {
    'Track': ['Bahrain', 'Saudi Arabia', 'Australia', 'Emilia Romagna', 'Miami', 'Spain', 'Monaco', 'Azerbaijan', 'Canada', 'Great Britain',
              'Austria', 'France', 'Hungary', 'Belgium', 'Netherlands', 'Italy', 'Singapore', 'Japan', 'United States', 'Mexico',
              'Brazil', 'Abu Dhabi', 'Qatar', 'Las Vegas', 'China'],
    'Turns N°': [57, 50, 58, 63, 57, 66, 78, 51, 70, 52, 71, 53, 70, 44, 72, 53, 61, 27, 56, 71, 71, 58, 57, 50, 56],
    'Turns': ['Long', 'Long', 'Long', 'Short', 'Long', 'Short', 'Short', 'Long', 'Short', 'Long',
              'Short', 'Long', 'Short', 'Long', 'Short', 'Long', 'Short', 'Long', 'Long', 'Short',
              'Short', 'Long', 'Long', 'Long', 'Long']
}

df_turns = pd.DataFrame(data_turns)

# 2. Remover colunas duplicadas de df_race_median, se existirem
df_race_median = df_race_median.drop(columns=['Turns N°', 'Turns', 'Exchange Positions'], errors='ignore')

# 3. Merge limpo
df_race_statics = df_race_median.merge(df_turns, on='Track', how='left')

# 4. Criar coluna 'Exchange Positions' com arredondamento para cima, mantendo sinais negativos
def calcular_exchange(grid, pos):
    diferenca = grid - pos
    if diferenca >= 0:
        return int(np.ceil(diferenca))
    else:
        return int(-np.ceil(abs(diferenca)))

df_race_statics['Exchange Positions'] = df_race_statics.apply(
    lambda row: calcular_exchange(row['Median Grid'], row['Median Position']), axis=1
)

# 5. Função auxiliar para as colunas Top 3 e out Top 3
def ajustar_valor(median_grid, exchange_position, top3=True):
    if top3 and median_grid in [1, 2, 3]:
        return "-" if exchange_position == 0 else exchange_position
    elif not top3 and median_grid >= 4:
        return "-" if exchange_position == 0 else exchange_position
    else:
        return "-"

# 6. Criar colunas com a lógica de Top 3
df_race_statics['Starting Top 3°'] = df_race_statics.apply(
    lambda row: ajustar_valor(row['Median Grid'], row['Exchange Positions'], top3=True), axis=1
)

df_race_statics['Starting out Top 3°'] = df_race_statics.apply(
    lambda row: ajustar_valor(row['Median Grid'], row['Exchange Positions'], top3=False), axis=1
)

# 7. Salvar resultado final
df_race_statics_new = df_race_statics

# 8. Visualizar os primeiros registros
df_race_statics.head(2)
# Out:
#             Driver         Track  Median Grid  Median Position     Team  \
# 0  Charles Leclerc       Bahrain            2                1  Ferrari
# 1  Charles Leclerc  Saudi Arabia            2                3  Ferrari
#
#    Turns N° Turns  Exchange Positions Starting Top 3° Starting out Top 3°
# 0        57  Long                   1               1                   -
# 1        50  Long                  -1              -1                   -

# %%
# Salvar o DataFrame Lecrerc Record diretamente no S3
df_race_statics.to_csv("s3://testeguilherme-bucket1/f1consolidado/df_race_statics.csv", index=False)

# %% [markdown]
# # **Ánalises**
# ---

# %% [markdown]
# **1° Costuma largar no top 3° em qual tipo de circuito, voltas longas ou curtas:**
#
#
# ---

# %%
# Filtrar linhas onde 'Median Grid' está entre 1 e 3
df_filtrado = df_race_statics[df_race_statics['Median Grid'].between(1, 3)]

# Contar quantas vezes cada tipo de 'Turns' aparece
turns_count = df_filtrado['Turns'].value_counts()

# Plotar gráfico de barras
plt.figure(figsize=(6, 4))
ax = turns_count.plot(kind='bar', color=['#ef5350', '#ffd54f'])

# Adicionar os valores acima das barras
for i, value in enumerate(turns_count):
    plt.text(i, value / 2, f"{value:.1f}", ha='center', va='center', fontsize=10, fontweight='bold', color='black')

# Ajustar rótulos e título
plt.xlabel('Turns')
plt.ylabel('Quantity (Median | 2022 to 2024)')
plt.title('Races starting in the Top 3°')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.grid(False) # Remove a grade
plt.tight_layout()
plt.show()

# %% [markdown]
# **2° Quando larga no top três, perde ou ganha posições?:**
#
#
# ---

# %%
# 1. Filtrar apenas onde Median Grid está entre 1 e 3
df_filtrado = df_race_statics[df_race_statics['Median Grid'].between(1, 3)].copy()

# 2. Converter 'Starting Top 3°' para numérico (ignorar "-" transformando em NaN)
df_filtrado['Starting Top 3°'] = pd.to_numeric(df_filtrado['Starting Top 3°'], errors='coerce')

# 3. Agrupar por 'Turns' e calcular média
media_por_turn = df_filtrado.groupby('Turns')['Starting Top 3°'].mean()

# 4. Plotar gráfico de barras com as cores preferidas
plt.figure(figsize=(6, 4))
ax = media_por_turn.plot(kind='bar', color=['#ef5350', '#ffd54f'])

# 5. Adicionar os valores no topo das barras
for i, value in enumerate(media_por_turn):
    plt.text(i, value / 2, f"{value:.1f}", ha='center', va='center', fontsize=10, fontweight='bold', color='black')

# 6. Ajustes de layout
plt.xlabel('Turns')
plt.ylabel('Grid Evolution (Median | 2022 to 2024)')
plt.title('Performance starting TOP 3°')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.grid(False) # Remove a grade
plt.tight_layout()
plt.show()

# %% [markdown]
# **3° Quando larga fora do top três, perde ou ganha posições?:**
#
#
# ---

# %%
# 1. Filtrar onde 'Median Grid' é maior ou igual a 4
df_filtrado = df_race_statics[df_race_statics['Median Grid'] >= 4].copy()

# 2. Converter a coluna 'Starting out Top 3°' para numérico (ignorar "-" transformando em NaN)
df_filtrado['Starting out Top 3°'] = pd.to_numeric(df_filtrado['Starting out Top 3°'], errors='coerce')

# 3. Calcular a média da coluna agrupada por 'Turns'
media_por_turn = df_filtrado.groupby('Turns')['Starting out Top 3°'].mean()

# 4. Plotar gráfico de barras
plt.figure(figsize=(6, 4))
ax = media_por_turn.plot(kind='bar', color=['#ef5350', '#ffd54f'])

# 5. Adicionar os valores no centro das barras
for i, value in enumerate(media_por_turn):
    plt.text(i, value / 2, f"{value:.1f}", ha='center', va='center', fontsize=10, fontweight='bold', color='black')

# 6. Ajustes finais do gráfico
plt.xlabel('Turns')
plt.ylabel('Grid Evolution (Median | 2022 to 2024)')
plt.title('Performance starting OUTSIDE the TOP 3°')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.grid(False) # Remove a grade
plt.tight_layout()
plt.show()

# %% [markdown]
# **4° Finaliza a corrida melhor em pistas de voltas Longas ou Curtas?:**
#
#
# ---

# %%
# Filtrar apenas valores positivos na coluna 'Exchange Positions'
df_positive = df_race_statics[df_race_statics['Exchange Positions'] > 0]

# Contar quantos campos positivos existem por tipo de pista
contagem_positivos = df_positive['Turns'].value_counts()

# Reordenar para mostrar sempre 'Long' e 'Short'
contagem_positivos = contagem_positivos.reindex(['Long', 'Short']).fillna(0)

# Gráfico
plt.figure(figsize=(6, 4))
bars = plt.bar(contagem_positivos.index, contagem_positivos.values,
               color=['#ffd54f', '#ef5350'])

# Adicionar os valores no centro de cada barra
for bar in bars:
    altura = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, altura / 2,
             f'{int(altura)}',
             ha='center', va='center', fontsize=12, fontweight='bold', color='black')

plt.title('Grid Evolution by Track Type')
plt.xlabel('Track Type (Turns)')
plt.ylabel('Quantity (Median | 2022 to 2024)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.grid(False) # Remove a grade
plt.tight_layout()
plt.show()

# %% [markdown]
# **5° Capacidade de converter Poles em vitórias:**
#
#
# ---

# %%
df_race_consolidado.head(2)
# Out:
#           Track  Position  No           Driver     Team  Starting Grid  Laps  \
# 0       Bahrain         1  16  Charles Leclerc  Ferrari              1    57
# 1  Saudi Arabia         2  16  Charles Leclerc  Ferrari              2    50
#
#   Time/Retired  Points Set Fastest Lap Fastest Lap Time  Year
# 0  1:37:33.584      26             Yes         1:34.570  2022
# 1       +0.549      19             Yes         1:31.634  2022

# %%
# 1. Filtrar apenas quem largou em 1º
largou_em_p1 = df_race_consolidado[df_race_consolidado['Starting Grid'] == 1]

# 2. Contar total de largadas em P1
total_largadas_p1 = len(largou_em_p1)

# 3. Contar quantos desses venceram (Position == 1)
vitorias_p1 = (largou_em_p1['Position'] == 1).sum()

# 4. Calcular percentual de conversão
percentual = (vitorias_p1 / total_largadas_p1) * 100 if total_largadas_p1 > 0 else 0

# 5. Plotar gráfico
labels = ['Poles', 'Victories']
valores = [total_largadas_p1, vitorias_p1]

plt.figure(figsize=(6, 4))
bars = plt.bar(labels, valores, color=['#ffd54f', '#ef5350'])

# 6. Adicionar os valores no topo das barras
for bar in bars:
    altura = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, altura / 2, f'{int(altura)}',
             ha='center', va='center', fontsize=11, fontweight='bold')




# 7. Exibir percentual abaixo do gráfico
plt.title(f'Pole Position to Victory Conversion\nConversion rate: {percentual:.1f}%', fontsize=13)
plt.ylabel('Number of Races | 2022 a 2024')
plt.ylim(0, max(valores) * 1.2)
plt.grid(False) # Remove a grade
plt.tight_layout()
plt.show()

# %% [markdown]
# **Desempenho: Posição de Largada x Posição Final**

# %%
from matplotlib.patches import Patch

# Exemplo de leitura do DataFrame
# df_race_consolidado = pd.read_csv('caminho/para/seuarquivo.csv')

# Remove dados inválidos da coluna 'Position'
df_filtrado = df_race_consolidado[
    ~df_race_consolidado['Position'].isin(['0', 'DQ', 'NC'])
].copy()

# Converte colunas para numérico
df_filtrado['Position'] = pd.to_numeric(df_filtrado['Position'], errors='coerce')
df_filtrado['Starting Grid'] = pd.to_numeric(df_filtrado['Starting Grid'], errors='coerce')

# Remove linhas com valores nulos
df_filtrado.dropna(subset=['Starting Grid', 'Position'], inplace=True)

# Conta frequência de cada par (Starting Grid, Position)
counts = df_filtrado.groupby(['Starting Grid', 'Position']).size().reset_index(name='count')

# Define cores conforme a frequência
def get_color(count):
    if count == 1:
        return 'red'
    elif count == 2:
        return 'yellow'
    elif count == 3:
        return 'gray'
    elif count == 4:
        return 'blue'
    else:
        return 'black'  # opcional para casos acima de 4

colors = [get_color(c) for c in counts['count']]

plt.figure(figsize=(12, 6))

# Criação do gráfico
plt.scatter(
    counts['Starting Grid'],
    counts['Position'],
    s=80,
    alpha=0.8,
    c=colors,
    edgecolors='white'
)

# Inverte o eixo Y (1 no topo)
plt.gca().invert_yaxis()

# Define limites manuais para o Y a partir de 1
y_min = 1
y_max = int(counts['Position'].max())
plt.ylim(y_max + 0.5, y_min - 0.5)

# Eixos X e Y com ticks inteiros
x_min = int(counts['Starting Grid'].min())
x_max = int(counts['Starting Grid'].max())
plt.xticks(range(x_min, x_max + 1))
plt.yticks(range(y_min, y_max + 1))

# Labels and Title
plt.xlabel('Starting Position', fontsize=12)
plt.ylabel('Finishing Position', fontsize=12)
plt.title('Performance: Start vs. Finish', fontsize=14)


# Adiciona legenda
legend_elements = [
    Patch(facecolor='red', edgecolor='white', label='Once only'),
    Patch(facecolor='yellow', edgecolor='white', label='Twice'),
    Patch(facecolor='gray', edgecolor='white', label='Three times'),
    Patch(facecolor='blue', edgecolor='white', label='Four times'),
    Patch(facecolor='black', edgecolor='white', label='Five >'),
]
plt.legend(handles=legend_elements, title='Frequency', loc='upper right')

# Remove a grade
plt.grid(False)

plt.show()
